# %%
from _shared import *
display(neon_css())
# Out:
#         <style>
#         :root { --cyber-cyan:#27E1FF; --cyber-pink:#FF3CAC; --cyber-yellow:#F9F871; }
#         .jp-CodeCell .jp-Cell-inputWrapper, div.code_cell div.input { display:none !important; }
#         .jp-RenderedHTMLCommon h1, .text_cell_render h1 { color:#087F99 !important; letter-spacing:0.02em; border-bottom:1px solid #B9C5D6; padding-bottom:0.3em; }
#         .jp-RenderedHTMLCommon h2, .text_cell_render h2 { color:#C21875 !important; }
#         .jp-RenderedHTMLCommon h3, .text_cell_render h3 { color:#6950C5 !important; }
#         .jp-RenderedHTMLCommon code, .text_cell_render code { color:#FF9F43 !important; background:#11152A !important; }
#         .jp-RenderedHTMLCommon blockquote, .text_cell_render blockquote { border-left:3px solid #27E1FF; background:#EEF3F9; padding:0.5rem 1rem; }
#         .sme-card { background:#11152A; border:1px solid #27304D; border-left:3px solid #27E1FF; border-radius:4px; padding:14px; margin:10px 0; }
#         </style>

# %% [markdown]
# # Strange Matter Engine Fundamentals Examination
#
# ## Aim
#
# Consolidate the scientific foundations from the preceding notebooks and diagnose where further study will produce the greatest gain. The examination contains **75 multiple-choice questions**. Every question has exactly three options: one correct answer and two scientifically plausible distractors.
#
# The examination covers:
#
# - chemistry and molecular representation;
# - graph theory and atom-state encoding;
# - graph cellular automata and emergence;
# - trajectories, attractors and dynamical fingerprints;
# - perturbation sensitivity and Lyapunov-analysis discipline;
# - backpropagation through time;
# - ridge regression; and
# - validation and scientific inference.
#
# ## Method
#
# Answer each question before revealing the explanation. The option order is shuffled, but the question order is fixed so that question numbers remain stable when we discuss them together. Your first submitted answer is recorded for the diagnostic; the explanation then teaches the underlying principle.
#
# The final table reports performance by scientific domain. A total score is useful, but expertise is better indicated by consistently strong reasoning across every domain. Record questions that felt uncertain even when the selected answer was correct: uncertainty identifies a valuable learning objective that raw scoring can miss.

# %% [markdown]
# ## Interactive examination
#
# Work through the questions without consulting the previous notebooks on the first pass. Afterwards, use the final diagnostic to revisit the relevant lesson and explain the corrected principle in your own words.

# %%
display(fundamentals_quiz())
# Out:
#         <div id="sme-quiz-5fce1ffe5b504bad87366595ebfb6954" class="sme-quiz">
#           <div class="quiz-status">
#             <strong class="quiz-progress-text">Question 1 of 75</strong>
#             <span class="quiz-score">Score: 0 / 0</span>
#           </div>
#           <div class="quiz-progress" aria-hidden="true"><span></span></div>
#           <p class="quiz-domain"></p>
#           <h3 class="quiz-question"></h3>
#           <form class="quiz-options"></form>
#           <div class="quiz-feedback" hidden></div>
#           <div class="quiz-actions">
#             <button type="button" class="quiz-submit">Check answer</button>
#             <button type="button" class="quiz-next" hidden>Next question</button>
#           </div>
#           <div class="quiz-results" hidden></div>
#         </div>
#         <style>
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 { color:#182235; font-family:system-ui,sans-serif; max-width:980px; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-status { display:flex; justify-content:space-between; gap:1rem; flex-wrap:wrap; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-progress { height:8px; background:#D9E2EE; margin:0.7rem 0 1rem; overflow:hidden; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-progress span { display:block; height:100%; width:0; background:#087F99; transition:width 180ms ease; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-domain { color:#6950C5; font-weight:700; margin:0.4rem 0; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-question { color:#182235 !important; margin-top:0.4rem; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-options { display:grid; gap:0.65rem; margin:1rem 0; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-option { display:flex; align-items:flex-start; gap:0.65rem; padding:0.8rem; border:1px solid #B9C5D6; background:#F7F9FC; cursor:pointer; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-option:hover { border-color:#087F99; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-option.correct { border-color:#15805D; background:#E9F7F1; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-option.incorrect { border-color:#C2185B; background:#FCECF3; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-option input { margin-top:0.2rem; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-feedback { border-left:4px solid #087F99; background:#EEF3F9; padding:0.85rem 1rem; margin:1rem 0; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-actions { display:flex; gap:0.7rem; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 button { border:0; padding:0.65rem 1rem; background:#087F99; color:white; font-weight:700; cursor:pointer; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 button:disabled { opacity:0.5; cursor:not-allowed; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-next { background:#6950C5; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-results table { border-collapse:collapse; width:100%; margin-top:1rem; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-results th, #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-results td { border-bottom:1px solid #C8D3E0; padding:0.5rem; text-align:left; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-results th { color:#087F99; }
#           #sme-quiz-5fce1ffe5b504bad87366595ebfb6954 .quiz-results .review { margin-top:1rem; }
#         </style>
#         <script>
#         (() => {
#           const root = document.getElementById("sme-quiz-5fce1ffe5b504bad87366595ebfb6954");
#           const source = [{"domain": "Chemistry", "question": "What does an atom's formal charge represent?", "options": ["Integer electron-bookkeeping relative to a neutral valence model", "A continuously measured partial charge", "The total charge of the complete molecule"], "correct": 0, "explanation": "Formal charge is an integer bookkeeping quantity assigned by a valence model. Partial charge is continuous and method-dependent; molecular charge is the sum over atoms."}, {"domain": "Chemistry", "question": "Which statement best distinguishes aromaticity from conjugation?", "options": ["Aromaticity is cyclic stabilised conjugation; conjugation can also be non-cyclic", "Every conjugated system is aromatic", "Aromaticity requires only alternating single and double bonds"], "correct": 0, "explanation": "Conjugation is orbital communication across adjacent atoms. Aromaticity adds cyclicity, planarity and an appropriate electron count; conjugated chains need not be aromatic."}, {"domain": "Chemistry", "question": "Why are the two C–O bonds in a deprotonated carboxylate treated as a conjugated unit?", "options": ["The negative charge and pi bonding are delocalised across both oxygens", "Both oxygens must each carry a permanent charge of minus one", "The carbon atom becomes tetrahedral and blocks orbital overlap"], "correct": 0, "explanation": "Resonance delocalises the carboxylate's negative charge and pi character over both oxygens. The group has total charge minus one, not minus two."}, {"domain": "Chemistry", "question": "What does atomic hybridisation primarily describe in this project?", "options": ["The atom's local orbital geometry and bonding arrangement", "The molecule's measured inhibition potency", "Whether the complete molecule is aromatic"], "correct": 0, "explanation": "Hybridisation is a local structural description such as sp, sp2 or sp3. It is not a molecular assay label."}, {"domain": "Chemistry", "question": "Why must hydrogen-bond donor and acceptor status be determined from chemical context?", "options": ["The same element can behave differently according to bonding, charge and protonation", "Only carbon atoms can donate hydrogen bonds", "Donor and acceptor status is determined solely by atomic mass"], "correct": 0, "explanation": "Element identity alone is insufficient. For example, protonation and resonance can change whether a nitrogen has an available lone pair."}, {"domain": "Chemistry", "question": "Which quantity is a molecule-level experimental label rather than an intrinsic atom property?", "options": ["Experimental pIC50", "Formal charge", "Hybridisation"], "correct": 0, "explanation": "pIC50 comes from an inhibition experiment on a molecule–target combination. Formal charge and hybridisation describe atoms in the molecular representation."}, {"domain": "Chemistry", "question": "What is pIC50 when IC50 is expressed in molar units?", "options": ["The negative base-10 logarithm of IC50", "The reciprocal of IC50", "The natural logarithm of IC50"], "correct": 0, "explanation": "pIC50 = -log10(IC50 in mol/L). Larger pIC50 therefore corresponds to a smaller IC50 and stronger measured inhibition."}, {"domain": "Chemistry", "question": "A one-unit increase in pIC50 corresponds to what change in molar IC50?", "options": ["A tenfold decrease", "A twofold increase", "No systematic change"], "correct": 0, "explanation": "Because pIC50 uses a negative base-10 logarithm, increasing pIC50 by one means IC50 is divided by ten."}, {"domain": "Chemistry", "question": "What is the main role of a canonical SMILES string in the teaching pipeline?", "options": ["Provide a reproducible text representation from which a molecular graph can be constructed", "Encode a measured three-dimensional binding pose", "Store the trained cellular-automaton parameters"], "correct": 0, "explanation": "SMILES encodes molecular connectivity and associated chemical annotations. It is converted into atoms and bonds, not an experimentally obse ...

# %% [markdown]
# ## Expert-learning cycle
#
# For every missed or uncertain question:
#
# 1. state why the chosen distractor was tempting;
# 2. identify the exact assumption that made it wrong;
# 3. derive or explain the correct principle without looking;
# 4. connect it to one molecular example or one equation; and
# 5. retest the concept after a delay.
#
# This converts recognition into recall, and recall into transferable scientific reasoning.
