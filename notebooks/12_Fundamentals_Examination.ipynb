# %%
from _shared import *
display(neon_css())
# Out:
#         <style>
#         :root { --cyber-cyan:#27E1FF; --cyber-pink:#FF3CAC; --cyber-yellow:#F9F871; }
#         .jp-CodeCell .jp-Cell-inputWrapper, div.code_cell div.input { display:none !important; }
#         .jp-RenderedHTMLCommon h1, .text_cell_render h1 { color:#087F99 !important; letter-spacing:0.02em; border-bottom:1px solid #B9C5D6; padding-bottom:0.3em; }
#         .jp-RenderedHTMLCommon h2, .text_cell_render h2 { color:#C21875 !important; }
#         .jp-RenderedHTMLCommon h3, .text_cell_render h3 { color:#6950C5 !important; }
#         .jp-RenderedHTMLCommon code, .text_cell_render code { color:#FF9F43 !important; background:#11152A !important; }
#         .jp-RenderedHTMLCommon blockquote, .text_cell_render blockquote { border-left:3px solid #27E1FF; background:#EEF3F9; padding:0.5rem 1rem; }
#         .sme-card { background:#11152A; border:1px solid #27304D; border-left:3px solid #27E1FF; border-radius:4px; padding:14px; margin:10px 0; }
#         </style>

# %% [markdown]
# # Strange Matter Engine Fundamentals Examination
#
# ## Aim
#
# Consolidate the scientific foundations from the preceding notebooks and diagnose where further study will produce the greatest gain. The examination contains **75 multiple-choice questions**. Every question has exactly three options: one correct answer and two scientifically plausible distractors.
#
# The examination covers:
#
# - chemistry and molecular representation;
# - graph theory and atom-state encoding;
# - graph cellular automata and emergence;
# - trajectories, attractors and dynamical fingerprints;
# - perturbation sensitivity and Lyapunov-analysis discipline;
# - backpropagation through time;
# - ridge regression; and
# - validation and scientific inference.
#
# ## Method
#
# Answer each question before revealing the explanation. The option order is shuffled, but the question order is fixed so that question numbers remain stable when we discuss them together. Your first submitted answer is recorded for the diagnostic; the explanation then teaches the underlying principle.
#
# The final table reports performance by scientific domain. A total score is useful, but expertise is better indicated by consistently strong reasoning across every domain. Record questions that felt uncertain even when the selected answer was correct: uncertainty identifies a valuable learning objective that raw scoring can miss.

# %% [markdown]
# ## Interactive examination
#
# Work through the questions without consulting the previous notebooks on the first pass. Afterwards, use the final diagnostic to revisit the relevant lesson and explain the corrected principle in your own words.

# %%
display(fundamentals_quiz())
# Out:
#         <div id="sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61" class="sme-quiz">
#           <div class="quiz-status">
#             <strong class="quiz-progress-text">Question 1 of 75</strong>
#             <span class="quiz-score">Score: 0 / 0</span>
#           </div>
#           <div class="quiz-progress" aria-hidden="true"><span></span></div>
#           <p class="quiz-domain"></p>
#           <h3 class="quiz-question"></h3>
#           <form class="quiz-options"></form>
#           <div class="quiz-feedback" hidden></div>
#           <div class="quiz-actions">
#             <button type="button" class="quiz-submit">Check answer</button>
#             <button type="button" class="quiz-next" hidden>Next question</button>
#           </div>
#           <div class="quiz-results" hidden></div>
#         </div>
#         <style>
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 { color:#182235; font-family:system-ui,sans-serif; max-width:980px; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-status { display:flex; justify-content:space-between; gap:1rem; flex-wrap:wrap; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-progress { height:8px; background:#D9E2EE; margin:0.7rem 0 1rem; overflow:hidden; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-progress span { display:block; height:100%; width:0; background:#087F99; transition:width 180ms ease; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-domain { color:#6950C5; font-weight:700; margin:0.4rem 0; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-question { color:#B7FF3C !important; margin-top:0.4rem; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-options { display:grid; gap:0.65rem; margin:1rem 0; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-option { display:flex; align-items:flex-start; gap:0.65rem; padding:0.8rem; border:1px solid #B9C5D6; background:#F7F9FC; cursor:pointer; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-option:hover { border-color:#087F99; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-option.correct { border-color:#15805D; background:#E9F7F1; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-option.incorrect { border-color:#C2185B; background:#FCECF3; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-option input { margin-top:0.2rem; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-feedback { border-left:4px solid #087F99; background:#EEF3F9; padding:0.85rem 1rem; margin:1rem 0; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-actions { display:flex; gap:0.7rem; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 button { border:0; padding:0.65rem 1rem; background:#087F99; color:white; font-weight:700; cursor:pointer; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 button:disabled { opacity:0.5; cursor:not-allowed; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-next { background:#6950C5; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-results table { border-collapse:collapse; width:100%; margin-top:1rem; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-results th, #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-results td { border-bottom:1px solid #C8D3E0; padding:0.5rem; text-align:left; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-results th { color:#087F99; }
#           #sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61 .quiz-results .review { margin-top:1rem; }
#         </style>
#         <script>
#         (() => {
#           const root = document.getElementById("sme-quiz-66fa5aa2e3f9461ebe01cb0081312f61");
#           const source = [{"domain": "Chemistry", "question": "What is the total formal charge of a deprotonated carboxylate group, COO−?", "options": ["Minus one", "Minus two", "Zero"], "correct": 0, "explanation": "The carboxylate group has one excess electron overall. Resonance distributes this minus-one charge across the two oxygens; it does not create two full negative charges."}, {"domain": "Chemistry", "question": "Why should protonation state be defined before molecular features are generated?", "options": ["It can alter formal charge, hydrogen-bonding behaviour and electronic structure", "It changes every carbon atom into nitrogen", "It determines the experimental CYP concentration"], "correct": 0, "explanation": "Adding or removing a proton can change formal charge, donor/acceptor status, aromatic descriptions and the initial graph features."}, {"domain": "Chemistry", "question": "Why is an aromatic bond not adequately described as an ordinary fixed single bond?", "options": ["Its bonding participates in a delocalised aromatic system", "It contains no electrons", "It can occur only between oxygen atoms"], "correct": 0, "explanation": "Aromatic bond annotations represent delocalised bonding within an aromatic system rather than one localised single bond."}, {"domain": "Chemistry", "question": "Which quantity is naturally defined for the complete molecule rather than one atom?", "options": ["Molecular weight", "Atomic number", "Atom hybridisation"], "correct": 0, "explanation": "Molecular weight is obtained from the entire composition. Atomic number and hybridisation describe individual atoms."}, {"domain": "Chemistry", "question": "What does a rotatable-bond count attempt to summarise?", "options": ["A component of molecular conformational flexibility", "The total formal charge", "The number of CYP enzymes inhibited"], "correct": 0, "explanation": "Rotatable bonds provide a simple topological proxy for conformational flexibility, subject to a precise chemical definition."}, {"domain": "Chemistry", "question": "Why can stereochemistry matter even when two molecules have the same atom connectivity?", "options": ["Different spatial arrangements can interact differently with a chiral protein environment", "Stereochemistry changes every atomic number", "Connectivity uniquely fixes every three-dimensional arrangement"], "correct": 0, "explanation": "Stereoisomers share connectivity but differ spatially. Proteins are chiral environments and can distinguish those arrangements."}, {"domain": "Chemistry", "question": "An IC50 of 1 micromolar equals 10⁻⁶ molar. What is its pIC50?", "options": ["6", "Minus 6", "1"], "correct": 0, "explanation": "pIC50 = -log10(10^-6) = 6."}, {"domain": "Chemistry", "question": "How much lower is the IC50 of a compound with pIC50 7 than one with pIC50 5?", "options": ["One hundred times lower", "Two times lower", "Seven-fifths lower"], "correct": 0, "explanation": "A difference of two logarithmic units corresponds to 10^2 = 100-fold in molar IC50."}, {"domain": "Chemistry", "question": "Why must a pIC50 value be stored with its CYP target?", "options": ["Inhibition potency is specific to the molecule–target assay context", "A molecule has a universal pIC50 independent of protein", "The target determines the molecule's atomic numbers"], "correct": 0, "explanation": "The same molecule may inhibit different CYP enzymes with different potencies, so target identity is part of the label context."}, {"domain": "Chemistry", "question": "Which system can be conjugated without being aromatic?", "options": ["An open-chain sequence of overlapping p orbitals", "A saturated isolated methane molecule", "Any atom with sp3 hybridisation only"], "correct": 0, "explanation": "Conjugation can extend along an acyclic chain. Aromaticity additionally requires a suitable cyclic, planar electron system."}, {"domain": "Chemistry", "question": "What is the principal limitation of using electronegativity alone as the initial ...

# %% [markdown]
# ## Expert-learning cycle
#
# For every missed or uncertain question:
#
# 1. state why the chosen distractor was tempting;
# 2. identify the exact assumption that made it wrong;
# 3. derive or explain the correct principle without looking;
# 4. connect it to one molecular example or one equation; and
# 5. retest the concept after a delay.
#
# This converts recognition into recall, and recall into transferable scientific reasoning.
